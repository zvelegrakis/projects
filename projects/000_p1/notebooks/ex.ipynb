# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       2 import matplotlib.pyplot as plt
#       4 # --- Israel monthly fatalities (from ACLED) ---
#       5 # We already have df_pol with a 'date' column
#       6 df_israel_monthly = (
# ----> 7     df_pol
#       8     .set_index("date")
#       9     .resample("M")["Fatalities"]
#      10     .sum()
#      11     .to_frame(name="israel_fatalities")
#      12 )
#      14 df_israel_monthly.head()
#
# NameError: name 'df_pol' is not defined
